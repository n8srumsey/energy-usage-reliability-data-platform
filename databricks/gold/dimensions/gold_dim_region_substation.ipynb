# %%
from pyspark.sql import functions as F

CATALOG = "energy_data_platform_project"
GOLD_SCHEMA = f"{CATALOG}.gold"

# %%
daily = spark.table(f"{GOLD_SCHEMA}.daily_region_usage")

# %%
dim_region_sub = (
    daily
    .select("region_id", "substation_id", "city")
    .dropDuplicates()
)

# %%
(
    dim_region_sub
    .write
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(f"{GOLD_SCHEMA}.dim_region_substation")
)

# %%
display(spark.table(f"{GOLD_SCHEMA}.dim_region_substation").limit(10))
